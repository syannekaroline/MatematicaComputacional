# %% [markdown]
# ## Exercício Prático 03 - Syanne Karoline Moreira Tavares
#
# ### Métodos de Refinamento
#
# #### 01. Implemente 3 métodos de refinamento para encontrar raízes reais de funções reais

# %% [markdown]
# * 1° - método da bissecção.

# %%
def precisao_maquina():
    """Função que calcula a precisão da máquina com referência igual a 1"""
    A=1
    S=2

    while(S>1):
        A=A/2
        S=1+A
    prec=2*A

    return prec
def bisseccao(funcao,intervalo,erro=precisao_maquina()):
  """Função que realiza o método da bissecção pra achar a raiz real de uma função.
  Parâmetros:
  função : função pro cálculo ex: função = lambda x:x**3-9*x+3 
  intevalo: lista contendo o intervalo considerado da função. ex: [-1,1]
  erro: critério de parada pra precisão requerida ex:  0.000000001 
  Retorna uma tupla contendo a raiz, o y na raiz e o número de iterções realizadas, respectivamente."""

  ai = intervalo[0] 
  bi = intervalo[1]
  i = 0 # variável q armazena o número de iterações realizadas ( bissecções realizadas)
  # verificar se o método se aplica a função
  if funcao(ai)*funcao(bi)< 0:

    while abs(bi-ai) > erro: # testa o critério de parada: enquanto a diferença entre intervalo for maior que o erro -> enquanto f(pi) > precisão
      #calcula o ponto médio
      pi = (ai + bi)/2
      #print("a{}: {};  b{}: {};  p{}: {};".format(i,ai,i,bi,i,pi)) # Mostre todos os passos do algoritmo com os valores de 𝑎𝑖, 𝑏𝑖 e 𝑝i

      # realiza a bissecção no intervalo verificando o sinal das extremidades na função
      if funcao(ai)*funcao(pi)<0: # significa que a raíz pertence a esse intervalo -> está mais a esquerda de bi
          bi = pi
      else: # a raiz está mais a direita de ai -> diminui o intervalo fazendo ai receber o ponto médio calculado
          ai = pi
      i+=1
    return (pi,funcao(pi),i)
  else:
    print("Não existe raíz real neste intervalo!")

# %%
import math
#exemplo f(x) = e**-x^2 - cos(x), [1,2], e = 10 **-4
result= bisseccao(lambda x : math.exp(-x**2) - math.cos(x),[1,2],10**-4)
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# Raiz X = 1.44744873046875
# f(X) = 2.192118039383295e-05
# N iterações = 14

# %%
result= bisseccao(lambda x : (x**5) + (4*x**3) +4*x + 2,[-1,2],precisao_maquina())
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# Raiz X = -0.4216839617778975
# f(X) = -4.440892098500626e-16
# N iterações = 54

# %%
result= bisseccao(lambda x :  x *math.log(x) - 1,[1,3],precisao_maquina())
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# Raiz X = 1.7632228343518965
# f(X) = -3.3306690738754696e-16
# N iterações = 53

# %% [markdown]
# * 2° - Método da posição falsa.

# %%
def posicaoFalsa(funcao, intervalo, erro=precisao_maquina(),erro2 = precisao_maquina(),it_max = 100000):
    """Função que realiza o método da posição falsa pra achar aproximação da raiz real de uma função.
    Parâmetros:
    função : função pro cálculo ex: função = lambda x:x**3-9*x+3 
    intevalo: lista contendo o intervalo considerado da função. ex: [-1,1]
    erro: critério de parada pra precisão requerida ex:  0.000000001 
    Retorna uma tupla contendo a raiz, o y na raiz e o número de iterções realizadas, respectivamente."""
    ai = intervalo[0]
    bi = intervalo[1]
    x = (ai*funcao(bi) - bi*funcao(ai))/(funcao(bi) - funcao(ai))  # média ponderada
    i = 0 # variável q armazena o número de iterações realizadas ( bissecções realizadas)
    # verificar se o método se aplica a função
    # if funcao(ai)*funcao(bi)< 0:

    while abs(bi-ai) > erro and i<it_max and abs(funcao(x)) > erro2: # testa o critério de parada: enquanto a diferença entre intervalo for maior que o erro -> enquanto f(pi) > precisão
    #calcula o ponto médio
        x = (ai*funcao(bi) - bi*funcao(ai))/(funcao(bi) - funcao(ai))  # média ponderada
        #print("a{}: {};  b{}: {};  p{}: {};".format(i,ai,i,bi,i,pi)) # Mostre todos os passos do algoritmo com os valores de 𝑎𝑖, 𝑏𝑖 e 𝑝i

        # realiza a bissecção no intervalo verificando o sinal das extremidades na função
        if funcao(ai)*funcao(x)<0: # significa que a raíz pertence a esse intervalo -> está mais a esquerda de bi
            bi = x
        else: # a raiz está mais a direita de ai -> diminui o intervalo fazendo ai receber o ponto médio calculado
            ai = x
        i+=1
    return (x,funcao(x),i)
    # else:
    #     print("Não existe raíz real neste intervalo!")

# %% [markdown]
# * 3° - método do ponto fixo

# %%
def pontoFixo(f, phi, x0, e1=precisao_maquina(), e2=precisao_maquina(), it_max=1000000):
    """Função que calcula a raiz de uma função f recebida por parâmetro pelo método do ponto fixo.
    PArâmetros:
    f -> função 
    phi -> função equivalente tal que phi(X) = X -> veio de f(x)= 0 e depois de isolar x.
    x0 -> aproximação inicial 
    e1 e e2 -> precisões
    it_max -> número de iterações máximas.
    Retorna uma tupla contendo a raiz, o y na raiz e o número de iterções realizadas, respectivamente.
    """
    if (abs(f(x0)) < e1):
        return x0

    x = phi(x0)
    k = 0

    while (abs(f(x)) > e2 and abs(x - x0) > e1 and k < it_max):
        print("x{}: {}; f(x) : {}; ".format(k, x, f(x)))

        x0 = x
        x = phi(x)
        k += 1

    return (x, f(x), k)

# %%
def f(x):
    return x*math.exp(x) - 10
result= pontoFixo(f,lambda x : x - 0.05*f(x) ,1.5,10**-4,10**-4)
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# x0: 1.6638733197246451; f(x) : -1.2152125275455141;
# x1: 1.724633946101921; f(x) : -0.32399829547127723;
# x2: 1.7408338608754848; f(x) : -0.07359786447481831;
# x3: 1.7445137540992257; f(x) : -0.015942009263653745;
# x4: 1.7453108545624083; f(x) : -0.0034150016748100143;
# x5: 1.7454816046461488; f(x) : -0.0007297690789638267;
# Raiz X = 1.7455180931000969
# f(X) = -0.00015586694583014093
# N iterações = 6

# %%
#exemplo f(x) = e**-x^2 - cos(x), [1,2], e = 10 **-4 , phi(x)= cos(x) - e^-x**2 + x
result= pontoFixo(lambda x : math.exp(-x**2) - math.cos(x),lambda x : math.cos(x ) - math.exp(-x**2) + x,1.5,10**-4,10**-4)
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# x0: 1.4653379771058386; f(x) : 0.011545989928126763;
# x1: 1.4537919871777119; f(x) : 0.004075472071801228;
# x2: 1.4497165151059106; f(x) : 0.0014669381682340665;
# x3: 1.4482495769376764; f(x) : 0.0005316827564660481;
# x4: 1.4477178941812103; f(x) : 0.00019318660742757843;
# Raiz X = 1.4475247075737827
# f(X) = 7.025777685441825e-05
# N iterações = 5

# %%
result= pontoFixo(lambda x : math.sin(x) - 1,lambda x: x - 0.05*(math.sin(x) - 1),1,10**-4,10**-4)
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# x0: 1.007926450759605; f(x) : -0.15427281450767005;
# x1: 1.0156400914849886; f(x) : -0.15018189725245534;
# x2: 1.0231491863476114; f(x) : -0.14624802920017077;
# x3: 1.03046158780762; f(x) : -0.14246346804734;
# x4: 1.0375847612099869; f(x) : -0.13882092973340965;
# x5: 1.0445258076966573; f(x) : -0.13531355731144445;
# x6: 1.0512914855622295; f(x) : -0.1319348921627449;
# x7: 1.0578882301703667; f(x) : -0.12867884736594148;
# x8: 1.0643221725386638; f(x) : -0.12553968304695218;
# x9: 1.0705991566910114; f(x) : -0.12251198355073833;
# x10: 1.0767247558685482; f(x) : -0.11959063628913813;
# x11: 1.082704287683005; f(x) : -0.11677081213128415;
# x12: 1.0885428282895693; f(x) : -0.11404794721431089;
# x13: 1.0942452256502848; f(x) : -0.11141772606230382;
# x14: 1.0998161119534; f(x) : -0.10887606591081422;
# x15: 1.1052599152489406; f(x) : -0.10641910214282913;
# x16: 1.110580870356082; f(x) : -0.10404317474992009;
# x17: 1.115783029093578; f(x) : -0.10174481573944771;
# x18: 1.1208702698805504; f(x) : -0.09952073741524037;
# x19: 1.1258463067513125; f(x) : -0.09736782146513945;
# x20: 1.1307146978245695; f(x) : -0.09528310879426383;
# x21: 1.1354788532642826; f(x) : -0.09326379004783802;
# x22: 1.1401420427666744; f(x) : -0.09130719677198762;
# x23: 1.1447074026052737; f(x) : -0.0894107931650785;
# x24: 1.1491779422635275; f(x) : -0.08757216837598691;
# x25: 1.1535565506823269; f(x) : -0.08578902930918109;
# x26: 1.1578460021477859; f(x) : -0.08405919389967997;
# x27: 1.1620489618427698; f(x) : -0.08238058482388466;
# x28: 1.1661679910839642; f(x) : -0.0807512236149468;
# x29: 1.1702055522647115; f(x) : -0.07916922515379299;
# x30: 1.1741640135224012; f(x) : -0.07763279250916888;
# x31: 1.1780456531478596; f(x) : -0.07614021210212574;
# x32: 1.1818526637529658; f(x) : -0.07468984917225885;
# x33: 1.1855871562115787; f(x) : -0.07328014352474299;
# x34: 1.1892511633878158; f(x) : -0.0719096055387991;
# x35: 1.1928466436647558; f(x) : -0.07057681241968417;
# x36: 1.19637548428574; f(x) : -0.06928040467764462;
# x37: 1.1998395045196222; f(x) : -0.06801908281850111;
# x38: 1.2032404586605472; f(x) : -0.06679160423167019;
# x39: 1.2065800388721306; f(x) : -0.06559678026247229;
# x40: 1.2098598778852543; f(x) : -0.06443347345653638;
# x41: 1.213081551558081; f(x) : -0.06330059496499585;
# x42: 1.2162465813063308; f(x) : -0.06219710209998475;
# x43: 1.21935643641133; f(x) : -0.061121996030701564;
# x44: 1.222412536212865; f(x) : -0.06007431961099163;
# x45: 1.2254162521934147; f(x) : -0.0590531553300474;
# x46: 1.228368909959917; f(x) : -0.05805762337841336;
# x47: 1.2312717911288378; f(x) : -0.057086879822028314;
# x48: 1.2341261351199393; f(x) : -0.05614011487754056;
# x49: 1.2369331408638162; f(x) : -0.055216551282604165;
# x50: 1.2396939684279464; f(x) : -0.0543154427552861;
# x51: 1.2424097405657109; f(x) : -0.05343607253712346;
# x52: 1.2450815441925671; f(x) : -0.05257775201473214;
# x53: 1.2477104317933037; f(x) : -0.051739819415215105;
# x54: 1.2502974227640644; f(x) : -0.05092163857093357;
# x55: 1.2528435046926112; f(x) : -0.05012259774950123;
# x56: 1.2553496345800863; f(x) : -0.04934210854513155;
# x57: 1.2578167400073428; f(x) : -0.0485796048277245;
# x58: 1.260245720248729; f(x) : -0.047834541746313186;
# x59: 1.2626374473360447; f(x) : -0.047106394783708594;
# x60: 1.2649927670752301; f(x) : -0.046394658859387095;
# x61: 1.2673125000181995; f(x) : -0.04569884747784947;
# x62: 1.269597442392092; f(x) : -0.04501849191986074;
# x63: 1.271848366988085; f(x) : -0.04435314047414052;
# x64: 1.274066024011792; f(x) : -0.04370235770722741;
# x65: 1.2762511418971534; f(x) : -0.043065723769383;
# x66: 1.2784044280856226; f(x) : -0.04244283373453117;
# x67: 1.2805265697723491; f(x) : -0.04183329697235516;
# x68: 1.282618234620967; f(x) : -0.04123673655078697;
# x69: 1.2846800714485063; f(x) : -0.04065278866723088;
# x70: 1.286712710881868; f(x) : -0.040081102106967026;
# x71: 1.2887167659872163; f(x) : -0.03952133772726785;
# x72: 1.2906928328735796; f(x) : -0.03897316796585448;
# x73: 1.2926414912718722; f(x) : -0.038436276372396105;
# x74: 1.2945633050904921; f(x) : -0.03791035716183666;
# x75: 1.2964588229485838; f(x) : -0.03739511478839974;
# x76: 1.2983285786880039; f(x) : -0.03689026353919389;
# x77: 1.3001730918649637; f(x) : -0.03639552714640004;
# x78: 1.3019928682222837; f(x) : -0.03591063841708253;
# x79: 1.3037884001431377; f(x) : -0.03543533887972061;
# x80: 1.3055601670871237; f(x) : -0.03496937844660741;
# x81: 1.3073086360094541; f(x) : -0.03451251509131281;
# x82: 1.3090342617640198; f(x) : -0.03406451454045112;
# x83: 1.3107374874910425; f(x) : -0.03362514997903765;
# x84: 1.3124187449899944; f(x) : -0.03319420176875776;
# x85: 1.3140784550784324; f(x) : -0.0327714571785086;
# x86: 1.3157170279373578; f(x) : -0.032356710126610344;
# x87: 1.3173348634436883; f(x) : -0.03194976093411617;
# x88: 1.3189323514903941; f(x) : -0.03155041608868048;
# x89: 1.320509872294828; f(x) : -0.031158488018475317;
# x90: 1.322067796695752; f(x) : -0.030773794875671556;
# x91: 1.3236064864395356; f(x) : -0.030396160329028032;
# x92: 1.325126294455987; f(x) : -0.03002541336515463;
# x93: 1.3266275651242447; f(x) : -0.02966138809803953;
# x94: 1.3281106345291467; f(x) : -0.029303923586453506;
# x95: 1.3295758307084693; f(x) : -0.02895286365886085;
# x96: 1.3310234738914124; f(x) : -0.028608056745489163;
# x97: 1.3324538767286869; f(x) : -0.028269355717226774;
# x98: 1.3338673445145481; f(x) : -0.027936617731034064;
# x99: 1.3352641754010999; f(x) : -0.027609704081570263;
# x100: 1.3366446606051783; f(x) : -0.02728848005875284;
# x101: 1.3380090846081159; f(x) : -0.026972814810982793;
# x102: 1.339357725348665; f(x) : -0.02666258121377829;
# x103: 1.3406908544093539; f(x) : -0.026357655743576958;
# x104: 1.3420087371965328; f(x) : -0.02605791835647464;
# x105: 1.3433116331143564; f(x) : -0.025763252371684864;
# x106: 1.3445997957329408; f(x) : -0.025473544359506883;
# x107: 1.345873472950916; f(x) : -0.025188684033609743;
# x108: 1.3471329071525966; f(x) : -0.024908564147439916;
# x109: 1.3483783353599685; f(x) : -0.024633080394576234;
# x110: 1.3496099893796973; f(x) : -0.024362131312861024;
# x111: 1.3508280959453405; f(x) : -0.02409561819214512;
# x112: 1.3520328768549477; f(x) : -0.023833444985493668;
# x113: 1.3532245491042223; f(x) : -0.023575518223704073;
# x114: 1.3544033250154075; f(x) : -0.023321746932997156;
# x115: 1.3555694123620574; f(x) : -0.023072042555748018;
# x116: 1.3567230144898448; f(x) : -0.022826318874129448;
# x117: 1.3578643304335511; f(x) : -0.022584491936546214;
# x118: 1.3589935550303784; f(x) : -0.022346479986744994;
# x119: 1.3601108790297156; f(x) : -0.022112203395489916;
# x120: 1.36121648919949; f(x) : -0.02188158459469791;
# x121: 1.362310568429225; f(x) : -0.021654548013934183;
# x122: 1.3633932958299217; f(x) : -0.02143102001917152;
# x123: 1.3644648468308804; f(x) : -0.021210928853721667;
# x124: 1.3655253932735665; f(x) : -0.020994204581252673;
# x125: 1.366575103502629; f(x) : -0.020780779030807106;
# x126: 1.3676141424541695; f(x) : -0.02057058574374293;
# x127: 1.3686426717413567; f(x) : -0.02036355992251948;
# x128: 1.3696608497374827; f(x) : -0.02015963838125756;
# x129: 1.3706688316565456; f(x) : -0.019958759498001744;
# x130: 1.3716667696314457; f(x) : -0.019760863168620246;
# x131: 1.3726548127898768; f(x) : -0.019565890762278437;
# x132: 1.3736331073279906; f(x) : -0.019373785078423467;
# x133: 1.3746017965819117; f(x) : -0.019184490305224067;
# x134: 1.375561021097173; f(x) : -0.01899795197940879;
# x135: 1.3765109186961433; f(x) : -0.018814116947448167;
# x136: 1.3774516245435158; f(x) : -0.018632933328032064;
# x137: 1.3783832712099173; f(x) : -0.018454350475790804;
# x138: 1.379305988733707; f(x) : -0.0182783189462159;
# x139: 1.3802199046810177; f(x) : -0.01810479046173208;
# x140: 1.3811251442041044; f(x) : -0.01793371787888154;
# x141: 1.3820218300980485; f(x) : -0.017765055156575782;
# x142: 1.3829100828558774; f(x) : -0.017598757325377634;
# x143: 1.3837900207221463; f(x) : -0.01743478045777458;
# x144: 1.384661759745035; f(x) : -0.017273081639407883;
# x145: 1.3855254138270054; f(x) : -0.01711361894122121;
# x146: 1.3863810947740665; f(x) : -0.016956351392497293;
# x147: 1.3872289123436914; f(x) : -0.016801238954748943;
# x148: 1.388068974291429; f(x) : -0.01664824249643493;
# x149: 1.3889013864162507; f(x) : -0.016497323768469574;
# x150: 1.389726252604674; f(x) : -0.016348445380499288;
# x151: 1.390543674873699; f(x) : -0.016201570777918395;
# x152: 1.391353753412595; f(x) : -0.016056664219597394;
# x153: 1.392156586623575; f(x) : -0.01591369075629967;
# x154: 1.39295227116139; f(x) : -0.015772616209761448;
# x155: 1.393740901971878; f(x) : -0.015633407152412127;
# x156: 1.3945225723294987; f(x) : -0.015496030887714007;
# x157: 1.3952973738738845; f(x) : -0.015360455431097764;
# x158: 1.3960653966454395; f(x) : -0.015226649491474786;
# x159: 1.3968267291200132; f(x) : -0.015094582453305971;
# x160: 1.3975814582426784; f(x) : -0.014964224359207967;
# x161: 1.3983296694606389; f(x) : -0.014835545893078894;
# x162: 1.3990714467552927; f(x) : -0.01470851836372522;
# x163: 1.399806872673479; f(x) : -0.01458311368897336;
# x164: 1.4005360283579276; f(x) : -0.014459304380250781;
# x165: 1.4012589935769402; f(x) : -0.014337063527617877;
# x166: 1.401975846753321; f(x) : -0.014216364785239022;
# x167: 1.4026866649925829; f(x) : -0.014097182357276195;
# x168: 1.4033915241104467; f(x) : -0.013979490984191378;
# x169: 1.4040904986596563; f(x) : -0.01386326592944509;
# x170: 1.4047836619561285; f(x) : -0.013748482966577047;
# x171: 1.4054710861044573; f(x) : -0.01363511836665754;
# x172: 1.4061528420227902; f(x) : -0.013523148886096292;
# x173: 1.406828999467095; f(x) : -0.01341255175479783;
# x174: 1.407499627054835; f(x) : -0.013303304664653126;
# x175: 1.4081647922880676; f(x) : -0.013195385758353884;
# x176: 1.4088245615759853; f(x) : -0.013088773618523009;
# x177: 1.4094790002569115; f(x) : -0.012983447257147507;
# x178: 1.410128172619769; f(x) : -0.01287938610530659;
# x179: 1.4107721419250343; f(x) : -0.012776570003184884;
# x180: 1.4114109704251936; f(x) : -0.012674979190361424;
# x181: 1.4120447193847117; f(x) : -0.012574594296366426;
# x182: 1.41267344909953; f(x) : -0.012475396331496524;
# x183: 1.4132972189161048; f(x) : -0.01237736667788214;
# x184: 1.413916087249999; f(x) : -0.01228048708079621;
# x185: 1.4145301116040387; f(x) : -0.012184739640200726;
# x186: 1.4151393485860488; f(x) : -0.012090106802520095;
# x187: 1.4157438539261749; f(x) : -0.01199657135263621;
# x188: 1.4163436824938067; f(x) : -0.011904116406098786;
# x189: 1.4169388883141116; f(x) : -0.0118127254015431;
# x190: 1.4175295245841888; f(x) : -0.011722382093309447;
# x191: 1.4181156436888542; f(x) : -0.011633070544258883;
# x192: 1.4186972972160672; f(x) : -0.011544775118778161;
# x193: 1.419274535972006; f(x) : -0.01145748047596895;
# x194: 1.4198474099958045; f(x) : -0.01137117156301548;
# x195: 1.4204159685739552; f(x) : -0.011285833608725482;
# x196: 1.4209802602543915; f(x) : -0.01120145211723933;
# x197: 1.4215403328602534; f(x) : -0.011118012861902282;
# x198: 1.4220962335033485; f(x) : -0.011035501879294585;
# x199: 1.4226480085973132; f(x) : -0.010953905463416014;
# x200: 1.423195703870484; f(x) : -0.010873210160018965;
# x201: 1.423739364378485; f(x) : -0.010793402761086535;
# x202: 1.4242790345165393; f(x) : -0.010714470299451051;
# x203: 1.4248147580315118; f(x) : -0.01063640004354971;
# x204: 1.4253465780336894; f(x) : -0.010559179492311999;
# x205: 1.425874537008305; f(x) : -0.010482796370176573;
# x206: 1.4263986768268138; f(x) : -0.010407238622232695;
# x207: 1.4269190387579254; f(x) : -0.010332494409483362;
# x208: 1.4274356634783996; f(x) : -0.010258552104227103;
# x209: 1.427948591083611; f(x) : -0.010185400285553259;
# x210: 1.4284578610978886; f(x) : -0.010113027734950153;
# x211: 1.428963512484636; f(x) : -0.010041423432020191;
# x212: 1.429465583656237; f(x) : -0.009970576550301424;
# x213: 1.429964112483752; f(x) : -0.009900476453190699;
# x214: 1.4304591363064116; f(x) : -0.009831112689967059;
# x215: 1.43095069194091; f(x) : -0.009762474991910741;
# x216: 1.4314388156905056; f(x) : -0.009694553268517647;
# x217: 1.4319235433539315; f(x) : -0.009627337603804187;
# x218: 1.4324049102341216; f(x) : -0.009560818252701386;
# x219: 1.4328829511467567; f(x) : -0.009494985637535813;
# x220: 1.4333577004286335; f(x) : -0.009429830344594325;
# x221: 1.4338291919458632; f(x) : -0.009365343120770975;
# x222: 1.4342974591019018; f(x) : -0.00930151487029307;
# x223: 1.4347625348454165; f(x) : -0.00923833665152518;
# x224: 1.4352244516779928; f(x) : -0.00917579967384885;
# x225: 1.4356832416616854; f(x) : -0.009113895294614482;
# x226: 1.436138936426416; f(x) : -0.009052615016166055;
# x227: 1.4365915671772245; f(x) : -0.008991950482934441;
# x228: 1.4370411647013712; f(x) : -0.008931893478598796;
# x229: 1.4374877593753013; f(x) : -0.008872435923313993;
# x230: 1.437931381171467; f(x) : -0.008813569871001126;
# x231: 1.438372059665017; f(x) : -0.00875528750670218;
# x232: 1.438809824040352; f(x) : -0.008697581143994104;
# x233: 1.4392447030975517; f(x) : -0.00864044322246249;
# x234: 1.4396767252586748; f(x) : -0.008583866305233556;
# x235: 1.4401059185739364; f(x) : -0.008527843076561181;
# x236: 1.4405323107277646; f(x) : -0.008472366339469573;
# x237: 1.440955929044738; f(x) : -0.008417429013449107;
# x238: 1.4413768004954104; f(x) : -0.008363024132203467;
# x239: 1.4417949517020205; f(x) : -0.008309144841448513;
# x240: 1.442210408944093; f(x) : -0.008255784396759114;
# x241: 1.442623198163931; f(x) : -0.00820293616146539;
# x242: 1.4430333449720043; f(x) : -0.00815059360459458;
# x243: 1.443440874652234; f(x) : -0.008098750298859647;
# x244: 1.4438458121671771; f(x) : -0.0080473999186913;
# x245: 1.4442481821631117; f(x) : -0.007996536238314644;
# x246: 1.4446480089750273; f(x) : -0.007946153129866573;
# x247: 1.4450453166315207; f(x) : -0.00789624456155602;
# x248: 1.4454401288595986; f(x) : -0.007846804595863288;
# x249: 1.4458324690893918; f(x) : -0.007797827387778566;
# x250: 1.4462223604587807; f(x) : -0.007749307183079868;
# x251: 1.4466098258179347; f(x) : -0.007701238316646819;
# x252: 1.446994887733767; f(x) : -0.007653615210811315;
# x253: 1.4473775684943075; f(x) : -0.007606432373744476;
# x254: 1.4477578901129948; f(x) : -0.007559684397876465;
# x255: 1.4481358743328887; f(x) : -0.0075133659583521695;
# x256: 1.4485115426308064; f(x) : -0.007467471811517856;
# x257: 1.4488849162213824; f(x) : -0.0074219967934413544;
# x258: 1.4492560160610544; f(x) : -0.007376935818462882;
# x259: 1.4496248628519774; f(x) : -0.007332283877776957;
# x260: 1.4499914770458664; f(x) : -0.0072880360380435105;
# x261: 1.4503558788477686; f(x) : -0.00724418744002886;
# x262: 1.45071808821977; f(x) : -0.007200733297274886;
# x263: 1.4510781248846338; f(x) : -0.007157668894795743;
# x264: 1.4514360083293736; f(x) : -0.007114989587801879;
# x265: 1.4517917578087636; f(x) : -0.007072690800450809;
# x266: 1.4521453923487861; f(x) : -0.007030768024623324;
# x267: 1.4524969307500173; f(x) : -0.006989216818724886;
# x268: 1.4528463915909535; f(x) : -0.006948032806512128;
# x269: 1.453193793231279; f(x) : -0.0069072116759433255;
# x270: 1.4535391538150761; f(x) : -0.006866749178051745;
# x271: 1.4538824912739787; f(x) : -0.006826641125842747;
# x272: 1.454223823330271; f(x) : -0.0067868833932132056;
# x273: 1.4545631674999315; f(x) : -0.0067474719138921335;
# x274: 1.4549005410956262; f(x) : -0.0067084026804036245;
# x275: 1.4552359612296464; f(x) : -0.00666967174305011;
# x276: 1.4555694448167988; f(x) : -0.006631275208916487;
# x277: 1.4559010085772446; f(x) : -0.00659320924089335;
# x278: 1.4562306690392892; f(x) : -0.006555470056721413;
# x279: 1.4565584425421252; f(x) : -0.006518053928052603;
# x280: 1.4568843452385278; f(x) : -0.006480957179532232;
# x281: 1.4572083930975044; f(x) : -0.006444176187897721;
# x282: 1.4575306019068992; f(x) : -0.00640770738109564;
# x283: 1.457850987275954; f(x) : -0.006371547237416397;
# x284: 1.4581695646378248; f(x) : -0.006335692284645589;
# x285: 1.458486349252057; f(x) : -0.006300139099232105;
# x286: 1.4588013562070186; f(x) : -0.006264884305472229;
# x287: 1.4591146004222921; f(x) : -0.006229924574710499;
# x288: 1.4594260966510277; f(x) : -0.006195256624554668;
# x289: 1.4597358594822554; f(x) : -0.006160877218107652;
# x290: 1.4600439033431607; f(x) : -0.006126783163212468;
# x291: 1.4603502425013213; f(x) : -0.006092971311713047;
# x292: 1.4606548910669068; f(x) : -0.006059438558729036;
# x293: 1.4609578629948432; f(x) : -0.006026181841943701;
# x294: 1.4612591720869403; f(x) : -0.005993198140906819;
# x295: 1.4615588319939856; f(x) : -0.005960484476349115;
# x296: 1.4618568562178031; f(x) : -0.005928037909511796;
# x297: 1.4621532581132788; f(x) : -0.005895855541486861;
# x298: 1.4624480508903532; f(x) : -0.005863934512571056;
# x299: 1.4627412476159818; f(x) : -0.005832272001631611;
# x300: 1.4630328612160635; f(x) : -0.005800865225484064;
# x301: 1.4633229044773377; f(x) : -0.005769711438281755;
# x302: 1.4636113900492518; f(x) : -0.00573880793091619;
# x303: 1.4638983304457975; f(x) : -0.005708152030429847;
# x304: 1.464183738047319; f(x) : -0.005677741099438305;
# x305: 1.464467625102291; f(x) : -0.005647572535564693;
# x306: 1.4647500037290693; f(x) : -0.005617643770883141;
# x307: 1.4650308859176133; f(x) : -0.005587952271373764;
# x308: 1.465310283531182; f(x) : -0.005558495536386765;
# x309: 1.4655882083080014; f(x) : -0.005529271098117072;
# x310: 1.4658646718629074; f(x) : -0.005500276521087866;
# x311: 1.4661396856889617; f(x) : -0.0054715094016444255;
# x312: 1.466413261159044; f(x) : -0.005442967367456086;
# x313: 1.4666854095274167; f(x) : -0.005414648077028739;
# x314: 1.466956141931268; f(x) : -0.005386549219224546;
# x315: 1.4672254693922293; f(x) : -0.005358668512791431;
# x316: 1.4674934028178688; f(x) : -0.005331003705900894;
# x317: 1.4677599530031638; f(x) : -0.005303552575693926;
# x318: 1.4680251306319485; f(x) : -0.005276312927834592;
# x319: 1.4682889462783402; f(x) : -0.005249282596073157;
# x320: 1.4685514104081439; f(x) : -0.005222459441815097;
# x321: 1.4688125333802347; f(x) : -0.005195841353699215;
# x322: 1.4690723254479197; f(x) : -0.005169426247182529;
# x323: 1.469330796760279; f(x) : -0.005143212064132818;
# x324: 1.4695879573634856; f(x) : -0.0051171967724280565;
# x325: 1.4698438172021069; f(x) : -0.005091378365563393;
# x326: 1.4700983861203851; f(x) : -0.005065754862264904;
# x327: 1.4703516738634983; f(x) : -0.005040324306109234;
# x328: 1.4706036900788038; f(x) : -0.005015084765151667;
# x329: 1.4708544443170612; f(x) : -0.004990034331558868;
# x330: 1.4711039460336393; f(x) : -0.00496517112124939;
# x331: 1.4713522045897016; f(x) : -0.004940493273539404;
# x332: 1.4715992292533786; f(x) : -0.004915998950795419;
# x333: 1.4718450292009184; f(x) : -0.004891686338092227;
# x334: 1.472089613517823; f(x) : -0.00486755364287772;
# x335: 1.4723329911999667; f(x) : -0.004843599094641937;
# x336: 1.4725751711546988; f(x) : -0.004819820944593878;
# x337: 1.4728161622019285; f(x) : -0.004796217465341757;
# x338: 1.4730559730751955; f(x) : -0.0047727869505801435;
# x339: 1.4732946124227246; f(x) : -0.004749527714781765;
# x340: 1.4735320888084638; f(x) : -0.004726438092895191;
# x341: 1.4737684107131086; f(x) : -0.004703516440046296;
# x342: 1.4740035865351109; f(x) : -0.004680761131246602;
# x343: 1.4742376245916733; f(x) : -0.004658170561104957;
# x344: 1.4744705331197285; f(x) : -0.004635743143544979;
# x345: 1.4747023202769058; f(x) : -0.004613477311526948;
# x346: 1.4749329941424822; f(x) : -0.004591371516774356;
# x347: 1.475162562718321; f(x) : -0.004569424229505237;
# x348: 1.4753910339297962; f(x) : -0.0045476339381673725;
# x349: 1.4756184156267045; f(x) : -0.004525999149178728;
# x350: 1.4758447155841634; f(x) : -0.004504518386671541;
# x351: 1.476069941503497; f(x) : -0.004483190192240971;
# x352: 1.476294101013109; f(x) : -0.004462013124697961;
# x353: 1.476517201669344; f(x) : -0.004440985759825766;
# x354: 1.4767392509573352; f(x) : -0.004420106690140924;
# x355: 1.4769602562918422; f(x) : -0.004399374524658106;
# x356: 1.4771802250180752; f(x) : -0.004378787888658087;
# x357: 1.4773991644125082; f(x) : -0.004358345423460919;
# x358: 1.4776170816836813; f(x) : -0.00433804578620145;
# x359: 1.4778339839729915; f(x) : -0.0043178876496090535;
# x360: 1.4780498783554719; f(x) : -0.004297869701790913;
# x361: 1.4782647718405615; f(x) : -0.00427799064601897;
# x362: 1.4784786713728624; f(x) : -0.004258249200519981;
# x363: 1.4786915838328885; f(x) : -0.004238644098268907;
# x364: 1.478903516037802; f(x) : -0.004219174086786404;
# x365: 1.4791144747421412; f(x) : -0.004199837927938099;
# x366: 1.4793244666385381; f(x) : -0.004180634397738747;
# x367: 1.479533498358425; f(x) : -0.004161562286158382;
# x368: 1.4797415764727329; f(x) : -0.0041426203969315845;
# x369: 1.4799487074925795; f(x) : -0.004123807547370628;
# x370: 1.480154897869948; f(x) : -0.004105122568180741;
# x371: 1.4803601539983569; f(x) : -0.004086564303278473;
# x372: 1.4805644822135209; f(x) : -0.004068131609613168;
# x373: 1.4807678887940015; f(x) : -0.004049823356991333;
# x374: 1.480970379961851; f(x) : -0.004031638427902995;
# x375: 1.4811719618832462; f(x) : -0.004013575717351836;
# x376: 1.4813726406691137; f(x) : -0.003995634132687109;
# x377: 1.481572422375748; f(x) : -0.003977812593438768;
# x378: 1.48177131300542; f(x) : -0.00396011003115504;
# x379: 1.4819693185069778; f(x) : -0.003942525389242002;
# x380: 1.4821664447764398; f(x) : -0.003925057622806261;
# x381: 1.48236269765758; f(x) : -0.003907705698500075;
# x382: 1.4825580829425051; f(x) : -0.003890468594368368;
# x383: 1.4827526063722236; f(x) : -0.0038733452996982942;
# x384: 1.4829462736372085; f(x) : -0.003856334814871798;
# x385: 1.4831390903779522; f(x) : -0.0038394361512189557;
# x386: 1.4833310621855131; f(x) : -0.003822648330874978;
# x387: 1.483522194602057; f(x) : -0.0038059703866391015;
# x388: 1.483712493121389; f(x) : -0.003789401361834588;
# x389: 1.4839019631894808; f(x) : -0.003772940310172279;
# x390: 1.4840906102049893; f(x) : -0.0037565862956154827;
# x391: 1.4842784395197701; f(x) : -0.003740338392246745;
# x392: 1.4844654564393824; f(x) : -0.003724195684137177;
# x393: 1.4846516662235894; f(x) : -0.003708157265217338;
# x394: 1.4848370740868502; f(x) : -0.0036922222391500004;
# x395: 1.4850216851988076; f(x) : -0.003676389719205475;
# x396: 1.4852055046847679; f(x) : -0.0036606588281380414;
# x397: 1.4853885376261748; f(x) : -0.0036450286980641566;
# x398: 1.485570789061078; f(x) : -0.0036294984703437727;
# x399: 1.4857522639845953; f(x) : -0.0036140672954615427;
# x400: 1.4859329673493684; f(x) : -0.0035987343329111354;
# x401: 1.486112904066014; f(x) : -0.0035834987510811045;
# x402: 1.486292079003568; f(x) : -0.0035683597271415346;
# x403: 1.4864704969899252; f(x) : -0.0035533164469337963;
# x404: 1.4866481628122719; f(x) : -0.003538368104860634;
# x405: 1.486825081217515; f(x) : -0.0035235139037785856;
# x406: 1.487001256912704; f(x) : -0.0035087530548914003;
# x407: 1.4871766945654485; f(x) : -0.0034940847776462336;
# x408: 1.4873513988043308; f(x) : -0.003479508299629508;
# x409: 1.4875253742193122; f(x) : -0.0034650228564662156;
# x410: 1.4876986253621356; f(x) : -0.0034506276917188883;
# x411: 1.4878711567467215; f(x) : -0.0034363220567895647;
# x412: 1.488042972849561; f(x) : -0.0034221052108225347;
# x413: 1.488214078110102; f(x) : -0.00340797642060775;
# x414: 1.4883844769311325; f(x) : -0.0033939349604871216;
# x415: 1.4885541736791568; f(x) : -0.0033799801122613715;
# x416: 1.4887231726847698; f(x) : -0.0033661111650974407;
# x417: 1.4888914782430247; f(x) : -0.003352327415438894;
# x418: 1.4890590946137967; f(x) : -0.0033386281669164353;
# x419: 1.4892260260221426; f(x) : -0.0033250127302600907;
# x420: 1.4893922766586556; f(x) : -0.0033114804232120543;
# x421: 1.4895578506798162; f(x) : -0.00329803057044209;
# x422: 1.4897227522083383; f(x) : -0.0032846625034627097;
# x423: 1.4898869853335115; f(x) : -0.0032713755605463524;
# x424: 1.4900505541115387; f(x) : -0.0032581690866434476;
# x425: 1.490213462565871; f(x) : -0.0032450424333020367;
# x426: 1.490375714687536; f(x) : -0.003231994958587725;
# x427: 1.4905373144354654; f(x) : -0.0032190260270057447;
# x428: 1.4906982657368157; f(x) : -0.003206135009423128;
# x429: 1.490858572487287; f(x) : -0.003193321282992767;
# x430: 1.4910182385514366; f(x) : -0.003180584231078143;
# x431: 1.4911772677629904; f(x) : -0.0031679232431792714;
# x432: 1.4913356639251494; f(x) : -0.0031553377148592077;
# x433: 1.4914934308108923; f(x) : -0.0031428270476725473;
# x434: 1.4916505721632758; f(x) : -0.003130390649093706;
# x435: 1.4918070916957304; f(x) : -0.0031180279324471982;
# x436: 1.4919629930923528; f(x) : -0.003105738316838247;
# x437: 1.4921182800081947; f(x) : -0.003093521227084728;
# x438: 1.492272956069549; f(x) : -0.003081376093650001;
# x439: 1.4924270248742315; f(x) : -0.0030693023525762975;
# x440: 1.4925804899918602; f(x) : -0.003057299445419326;
# x441: 1.4927333549641313; f(x) : -0.003045366819183881;
# x442: 1.4928856233050904; f(x) : -0.003033503926260117;
# x443: 1.4930372985014035; f(x) : -0.0030217102243605964;
# x444: 1.4931883840126217; f(x) : -0.003009985176458674;
# x445: 1.4933388832714445; f(x) : -0.0029983282507271003;
# x446: 1.4934887996839807; f(x) : -0.0029867389204776273;
# x447: 1.4936381366300047; f(x) : -0.002975216664102165;
# x448: 1.4937868974632098; f(x) : -0.0029637609650132735;
# x449: 1.4939350855114604; f(x) : -0.0029523713115869876;
# x450: 1.4940827040770397; f(x) : -0.0029410471971053065;
# x451: 1.494229756436895; f(x) : -0.0029297881196997944;
# x452: 1.49437624584288; f(x) : -0.0029185935822965137;
# x453: 1.4945221755219948; f(x) : -0.002907463092560736;
# x454: 1.494667548676623; f(x) : -0.0028963961628427626;
# x455: 1.4948123684847652; f(x) : -0.002885392310124968;
# x456: 1.4949566381002715; f(x) : -0.0028744510559687297;
# x457: 1.49510036065307; f(x) : -0.0028635719264625825;
# x458: 1.495243539249393; f(x) : -0.0028527544521709247;
# x459: 1.4953861769720016; f(x) : -0.0028419981680832818;
# x460: 1.4955282768804057; f(x) : -0.002831302613564679;
# x461: 1.4956698420110839; f(x) : -0.002820667332305904;
# x462: 1.495810875377699; f(x) : -0.0028100918722751;
# x463: 1.495951379971313; f(x) : -0.0027995757856698056;
# x464: 1.4960913587605964; f(x) : -0.002789118628869325;
# x465: 1.4962308146920398; f(x) : -0.0027787199623882097;
# x466: 1.4963697506901592; f(x) : -0.0027683793508299637;
# x467: 1.4965081696577007; f(x) : -0.0027580963628416333;
# x468: 1.4966460744758427; f(x) : -0.0027478705710684004;
# x469: 1.496783468004396; f(x) : -0.00273770155210995;
# x470: 1.4969203530820017; f(x) : -0.002727588886475729;
# x471: 1.4970567325263255; f(x) : -0.002717532158542646;
# x472: 1.4971926091342527; f(x) : -0.00270753095651155;
# x473: 1.4973279856820783; f(x) : -0.0026975848723655993;
# x474: 1.4974628649256965; f(x) : -0.0026876935018287362;
# x475: 1.4975972496007879; f(x) : -0.002677856444324056;
# x476: 1.497731142423004; f(x) : -0.0026680733029336157;
# x477: 1.4978645460881506; f(x) : -0.0026583436843587993;
# x478: 1.4979974632723685; f(x) : -0.002648667198879906;
# x479: 1.4981298966323124; f(x) : -0.002639043460317847;
# x480: 1.4982618488053283; f(x) : -0.00262947208599551;
# x481: 1.4983933224096282; f(x) : -0.002619952696699457;
# x482: 1.4985243200444631; f(x) : -0.002610484916642508;
# x483: 1.4986548442902952; f(x) : -0.0026010683734268847;
# x484: 1.4987848977089666; f(x) : -0.0025917026980072366;
# x485: 1.498914482843867; f(x) : -0.0025823875246547834;
# x486: 1.4990436022200997; f(x) : -0.0025731224909214534;
# x487: 1.4991722583446458; f(x) : -0.002563907237604579;
# x488: 1.499300453706526; f(x) : -0.00255474140871248;
# x489: 1.4994281907769615; f(x) : -0.002545624651429379;
# x490: 1.499555472009533; f(x) : -0.0025365566160823194;
# x491: 1.4996822998403372; f(x) : -0.0025275369561069683;
# x492: 1.4998086766881424; f(x) : -0.0025185653280148657;
# x493: 1.4999346049545432; f(x) : -0.002509641391360451;
# x494: 1.5000600870241112; f(x) : -0.0025007648087090883;
# x495: 1.5001851252645466; f(x) : -0.0024919352456049815;
# x496: 1.5003097220268269; f(x) : -0.002483152370539754;
# x497: 1.5004338796453538; f(x) : -0.0024744158549211415;
# x498: 1.5005576004380998; f(x) : -0.002465725373042682;
# x499: 1.500680886706752; f(x) : -0.0024570806020529634;
# x500: 1.5008037407368546; f(x) : -0.002448481221925869;
# x501: 1.5009261647979508; f(x) : -0.0024399269154307124;
# x502: 1.5010481611437223; f(x) : -0.0024314173681033724;
# x503: 1.5011697320121276; f(x) : -0.0024229522682170934;
# x504: 1.5012908796255384; f(x) : -0.002414531306753953;
# x505: 1.5014116061908762; f(x) : -0.0024061541773769957;
# x506: 1.5015319138997452; f(x) : -0.002397820576401921;
# x507: 1.5016518049285652; f(x) : -0.002389530202769774;
# x508: 1.5017712814387036; f(x) : -0.0023812827580199647;
# x509: 1.5018903455766046; f(x) : -0.002373077946262958;
# x510: 1.5020089994739179; f(x) : -0.0023649154741541834;
# x511: 1.5021272452476255; f(x) : -0.0023567950508674995;
# x512: 1.502245085000169; f(x) : -0.0023487163880694384;
# x513: 1.5023625208195723; f(x) : -0.0023406791998937804;
# x514: 1.502479554779567; f(x) : -0.0023326832029157973;
# x515: 1.5025961889397128; f(x) : -0.0023247281161278277;
# x516: 1.5027124253455193; f(x) : -0.0023168136609140744;
# x517: 1.502828266028565; f(x) : -0.002308939561026624;
# x518: 1.5029437130066163; f(x) : -0.0023011055425611326;
# x519: 1.5030587682837444; f(x) : -0.002293311333933179;
# x520: 1.503173433850441; f(x) : -0.0022855566658543935;
# x521: 1.5032877116837338; f(x) : -0.0022778412713094776;
# x522: 1.5034016037472993; f(x) : -0.0022701648855332213;
# x523: 1.503515111991576; f(x) : -0.0022625272459877444;
# x524: 1.5036282383538753; f(x) : -0.0022549280923400694;
# x525: 1.5037409847584922; f(x) : -0.0022473671664398065;
# x526: 1.5038533531168141; f(x) : -0.0022398442122973927;
# x527: 1.503965345327429; f(x) : -0.002232358976062332;
# x528: 1.5040769632762323; f(x) : -0.0022249112060018783;
# x529: 1.5041882088365324; f(x) : -0.0022175006524797203;
# x530: 1.5042990838691563; f(x) : -0.00221012706793533;
# x531: 1.5044095902225532; f(x) : -0.002202790206862981;
# x532: 1.5045197297328963; f(x) : -0.002195489825791541;
# x533: 1.504629504224186; f(x) : -0.0021882256832640445;
# x534: 1.5047389155083493; f(x) : -0.0021809975398179304;
# x535: 1.5048479653853402; f(x) : -0.0021738051579655027;
# x536: 1.5049566556432383; f(x) : -0.0021666483021738348;
# x537: 1.505064988058347; f(x) : -0.002159526738846007;
# x538: 1.5051729643952894; f(x) : -0.002152440236301789;
# x539: 1.5052805864071044; f(x) : -0.0021453885647589876;
# x540: 1.5053878558353424; f(x) : -0.002138371496314573;
# x541: 1.505494774410158; f(x) : -0.0021313888049264706;
# x542: 1.5056013438504043; f(x) : -0.0021244402663954665;
# x543: 1.505707565863724; f(x) : -0.002117525658346664;
# x544: 1.5058134421466414; f(x) : -0.002110644760212277;
# x545: 1.505918974384652; f(x) : -0.0021037973532140875;
# x546: 1.5060241642523127; f(x) : -0.0020969832203452388;
# x547: 1.5061290134133298; f(x) : -0.0020902021463542475;
# x548: 1.5062335235206477; f(x) : -0.0020834539177266853;
# x549: 1.506337696216534; f(x) : -0.0020767383226697467;
# x550: 1.5064415331326675; f(x) : -0.0020700551510944853;
# x551: 1.5065450358902222; f(x) : -0.002063404194599827;
# x552: 1.5066482060999522; f(x) : -0.002056785246456694;
# x553: 1.506751045362275; f(x) : -0.0020501981015912385;
# x554: 1.5068535552673545; f(x) : -0.002043642556569303;
# x555: 1.506955737395183; f(x) : -0.0020371184095810957;
# x556: 1.507057593315662; f(x) : -0.002030625460424762;
# x557: 1.5071591245886833; f(x) : -0.0020241635104919498;
# x558: 1.5072603327642078; f(x) : -0.002017732362752045;
# x559: 1.5073612193823454; f(x) : -0.0020113318217372944;
# x560: 1.5074617859734323; f(x) : -0.00200496169352804;
# x561: 1.5075620340581086; f(x) : -0.001998621785738064;
# Raiz X = 1.5076619651473955
# f(X) = -0.001992311907499711
# N iterações = 562

# %% [markdown]
# #### plus -> implementar todos os métodos
#
# - 4° Método de newton-Raphson

# %%
def newton_raphson(f, fdx, x0, e1=precisao_maquina(), e2=precisao_maquina(), it_max=100000):
    """Função que calcula a raiz de uma função f polinomial usando o método de newton-raphson
    parâmetros :
    f -> função f(x).
    fdx -> função derivada de f
    x0 -> aproximação inicial
    e1 e e2 -> precisões
    it_max -> número de iterações máximas.
    Retorna uma tupla contendo a raiz, o y na raiz e o número de iterções realizadas, respectivamente.
    """
    if (abs(f(x0)) < e1):
        return (x0,f(x0),0)

    x = x0 - (f(x0)/fdx(x0))
    print("x{}: {}; f(x) : {}; ".format(0, x0, f(x0)))
    k = 0

    while (abs(f(x)) > e2 and abs(x - x0) > e1 and k < it_max):
        # print("x{}: {}; f(x) : {}; ".format(k, x, f(x)))
        x0 = x
        x = x - (f(x)/fdx(x))
        k += 1

    return (x, f(x), k)

# %%
#exemplo f(x) = e**-x^2 - cos(x), [1,2], e = 10 **-4 , phi(x)= cos(x) - e^-x**2 + x
result= newton_raphson(lambda x: math.exp(-x**2) - math.cos(x),lambda x: -2*math.exp(-x**2) + math.sin(x),1.5,10**-4,10**-4)
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# x0: 1.5; f(x) : 0.034662022894161426;
# Raiz X = 1.4474422936781406
# f(X) = 1.7826338285120702e-05
# N iterações = 3

# %%
import sympy as sym
import math

from sympy import diff, Symbol
x = Symbol('x')
f = x**sym.sin(x) -1
diff(f, x)
# Out:
# x**sin(x)*(log(x)*cos(x) + sin(x)/x)

# %%
result= newton_raphson(lambda x:x**math.sin(x) - 1,lambda x: x**math.sin(x)*(math.log10(x)*math.cos(x)+(math.sin(x)/x)),0.5,10**-4,10**-4)
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# x0: 0.5; f(x) : -0.28273682848028714;
# Raiz X = 1.0000001403776526
# f(X) = 1.1812373101882656e-07
# N iterações = 2

# %% [markdown]
# - 5° Método da secante

# %%
def metodoSecante(f, x0, x1,e1= precisao_maquina(), e2 = precisao_maquina(), it_max=1000000):
    """Função que calcula a raiz de uma função f polinomial usando o método da secante
    parâmetros :
    f -> função f(x).\n
    x0 -> aproximação inicial\n
    x1= aproximação inicial 2\n
    e1 e e2 -> precisões\n
    it_max -> número de iterações máximas.
    Retorna uma tupla contendo a raiz, o y na raiz e o número de iterções realizadas, respectivamente.
    """
    if abs(f(x0)) < e1:
        return (x0, f(x0), 0)

    if (abs(f(x1)) < e1 or abs(x1 - x0) < e2):
        return (x1, f(x1), 0)

    x2 = x1 - (f(x1) / (f(x1) - f(x0))) * (x1 - x0)
    k = 0
    while (abs(f(x2)) > e1 and abs(x2 - x1) > e2 and k < it_max):
        x0 = x1
        x1 = x2
        x2 = x1 - ((f(x1) / (f(x1) - f(x0))) * (x1 - x0))
        k += 1
        # Mostre todos os passos do algoritmo com os valores de 𝑎𝑖, 𝑏𝑖 e 𝑝i
        # print("x{}: {}; f(x) : {}; ".format(k, x2, f(x2)))
    return (x2, f(x2), k)

# %%
result= metodoSecante(lambda x: x**2 + x - 6,1.5,1.7)
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# Raiz X = 2.0
# f(X) = 0.0
# N iterações = 5

# %%
#exemplo f(x) = e**-x^2 - cos(x), [1,2], e = 10 **-4 , phi(x)= cos(x) - e^-x**2 + x
result= metodoSecante(lambda x: math.exp(-x**2) - math.cos(x),1,2,10**-4,10**-4)
print(f'Raiz X = {result[0]}\nf(X) = {result[1]}\nN iterações = {result[2]}')
# Out:
# Raiz X = 1.4474134472158682
# f(X) = -5.242249916104225e-07
# N iterações = 4

# %% [markdown]
# ### Q2 - Teste esses algoritmos em 5 funções que misturam:
# ▪ Polinômios de graus > 5
#
# ▪ Logaritmos
#
# ▪ Exponenciais
#
# ▪ Senos e cossenos
#
# ▪ Divisões e raízes
#
# - Escolha os parâmetros iniciais. Use o algoritmo de testagem do sinal de 𝑓(𝑥) para encontrar o intervalo 𝐼. Mostre as tabelas testadas.
# - Monte uma tabela semelhante a dos exemplos anteriores.

# %%
# código pra gerar as tabelas
import pandas as pd, numpy as np
def ErroAbsoluto(exato,aproximado):
    """Calculo do erro absoluto = módulo da diferença entre o valor exato e o valor aproximado"""
    # print(exato-aproximado)
    return math.fabs(exato-aproximado)

def AvaliaSinalf(f,ValoresX=[-1,1],IsIntervalo = True):
    """Função que avalia os sinais de uma função em valores de x ou em dado intervalo
    Parâmetros:
    f -> função pra análise
    valoresX: Intervalo ou valores de x que deverão ser considerado na análise da função. Por padrão considera o intervalo de -1 até 1.
    IsIntervalo: por padrão recebe True. Se false siginifica que o parâmetro intervalo se refere aos valores de X que deverão ser considerados na análise."""
    #contruir a função
    analise={
        'x': ["f(x)"," sinal"]
    }
    desafio = {'x': ["f(x)"," sinal"]}
    if IsIntervalo :
        if  f(ValoresX[0]) == 0 :
                analise[f'{x}']= [f(x), "origem"]
        else:
            aux=list([f(ValoresX[0]), "+" if f(ValoresX[0]) > 0 else "-" ])# variável auxiliar pro desafio -> verificar apenas as trocas de sinal
            desafio[f'{ValoresX[0]}']=aux

        for x in range(ValoresX[0],ValoresX[1]+1):
            if  f(x) == 0 :
                analise[f'{x}']= [f(x), "origem"]
            else:
                analise[f'{x}'] =list([f(x), "+" if f(x) > 0 else "-" ])
            
            if analise[f'{x}'][1] != aux[1]: # se tiver mudança de sinal
                #guardar o dicionário do desafio
                desafio[f'{x}'] = analise[f'{x}']
                aux=analise[f'{x}']

    else: 
        for x in ValoresX:
            analise[f'{x}'] = list([f(x), "+" if f(x) > 0 else "-" ])
            aux=list([f(ValoresX[0]), "+" if f(ValoresX[0]) > 0 else "-" ])# variável auxiliar pro desafio -> verificar apenas as trocas de sinal
            if analise[f'{x}'][1] != aux[1]: # se tiver mudança de sinal
                #guardar o dicionário do desafio
                desafio[f'{x}'] = analise[f'{x}']
                aux=analise[f'{x}']
    
    tabelaAnalise=pd.DataFrame(analise)
    tabelaDesafio = pd.DataFrame(desafio)
    ##retorno ao usuário
    print("{:#^60}".format("Análise do sinal da função"))
    #print(f"\n f(x) = \n{f}\n")

    print("{:#^60}".format("Tabela de análise"))
    display(tabelaAnalise)
    print("{:#^60}".format("Tabela do desafio"))

    display(tabelaDesafio)


###########################

def exercicio02(f,intervalo,valorexatodeX,is_intervalo):
    """"Funçao do exercício 02. Recebe uma função e faz a testagem do sinal de f pra encontrar um intervalo que contém a raíz e mosta uma tabéla de análise dos métodos de refinamento"""

    AvaliaSinalf(f,intervalo,is_intervalo)

    ResultsBisseccao= bisseccao(f,intervalo,precisao_maquina())
    ResultsPosicaoFalsa = posicaoFalsa(f,intervalo)
    ResultsMetodoSecante = metodoSecante(f,intervalo[0],intervalo[1])
    # print(ResultsBisseccao)
    # print(ResultsPosicaoFalsa)
    # print(ResultsMetodoSecante)
    #construir a tabela de análise - 3 métodos : 1.Bissecção 2.Posição Falsa 3. método secante
    analise={
        'x = Raíz': ["Dados Iniciais","x"," f(x)","Erro em x","N° de Iterações"],
        'Bissecção': [f"{intervalo}",f'{ResultsBisseccao[0]}',f'{ResultsBisseccao[1]}',f'{ErroAbsoluto(valorexatodeX,ResultsBisseccao[0])}',ResultsBisseccao[2]],
        'Posição Falsa': [f"{intervalo}",f'{ResultsPosicaoFalsa[0]}',f'{ResultsPosicaoFalsa[1]}',f'{ErroAbsoluto(valorexatodeX,ResultsPosicaoFalsa[0])}',ResultsPosicaoFalsa[2]],
        'Secante': [f"{intervalo}",f'{ResultsMetodoSecante[0]}',f'{f(ResultsMetodoSecante[0])}',f'{ErroAbsoluto(valorexatodeX,ResultsMetodoSecante[0])}',ResultsMetodoSecante[2]]
        
    }
    tabelaAnalise=pd.DataFrame(analise)
    print("{:#^60}".format("Tabela de análise dos métodos de refinamento"))
    display(tabelaAnalise)

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# ### 1° Exemplo: x**5 - 10/9x ** 3 + 5/21x

# %%
def f(x):
    return x**5 + (10/9)*x**3 + (5/21)*x

exercicio02(f,[-1,1],0.59788607123,True)
# Out:
# #################Análise do sinal da função#################
# #####################Tabela de análise######################
#         x        -1       0         1
# 0    f(x) -2.349206     0.0  2.349206
# 1   sinal         -  origem         +
# #####################Tabela do desafio######################
#         x        -1       0         1
# 0    f(x) -2.349206     0.0  2.349206
# 1   sinal         -  origem         +
# ########Tabela de análise dos métodos de refinamento########
#           x = Raíz            Bissecção  Posição Falsa        Secante
# 0   Dados Iniciais              [-1, 1]        [-1, 1]        [-1, 1]
# 1                x   0.9999999999999998            0.0            0.0
# 2             f(x)   2.3492063492063475            0.0            0.0
# 3        Erro em x  0.40211392876999974  0.59788607123  0.59788607123
# 4  N° de Iterações                   53              0              0

# %% [markdown]
# ### *2° Exemplo* : f(x) = 4 * math.cos(x) - math.exp(2 * x)

# %%
import math

def f(x):
    return 4*math.cos(x) - math.exp(2*x)

exercicio02(f,[-1,1],0.59788607123,True)
# Out:
# #################Análise do sinal da função#################
# #####################Tabela de análise######################
#         x        -1    0         1
# 0    f(x)  2.025874  3.0 -5.227847
# 1   sinal         +    +         -
# #####################Tabela do desafio######################
#         x        -1         1
# 0    f(x)  2.025874 -5.227847
# 1   sinal         +         -
# ########Tabela de análise dos métodos de refinamento########
#           x = Raíz               Bissecção           Posição Falsa  \
# 0   Dados Iniciais                 [-1, 1]                 [-1, 1]
# 1                x      0.5978860670377386      0.5978860670377386
# 2             f(x)  -8.881784197001252e-16  -8.881784197001252e-16
# 3        Erro em x   4.192261426894106e-09   4.192261426894106e-09
# 4  N° de Iterações                      53                      35
#
#                   Secante
# 0                 [-1, 1]
# 1      0.5978860670377385
# 2   4.440892098500626e-16
# 3  4.1922615379164085e-09
# 4                      14

# %% [markdown]
# ### 3° Exemplo:q(x)=x^(5)+((10)/(9)) x+sqrt(x)-4

# %%
def f(x):
    return x**5 + (10/9)*x + (x**1/2) - 4
exercicio02(f,[1,3],1.1130427004953,True)
# Out:
# #################Análise do sinal da função#################
# #####################Tabela de análise######################
#         x         1          2           3
# 0    f(x) -1.388889  31.222222  243.833333
# 1   sinal         -          +           +
# #####################Tabela do desafio######################
#         x         1          2
# 0    f(x) -1.388889  31.222222
# 1   sinal         -          +
# ########Tabela de análise dos métodos de refinamento########
#           x = Raíz            Bissecção            Posição Falsa  \
# 0   Dados Iniciais               [1, 3]                   [1, 3]
# 1                x   1.1628731617041794       1.1628731617041774
# 2             f(x)                  0.0  -2.1316282072803006e-14
# 3        Erro em x  0.04983046120887935      0.04983046120887735
# 4  N° de Iterações                   53                   100000
#
#                Secante
# 0               [1, 3]
# 1   1.1628731617041794
# 2                  0.0
# 3  0.04983046120887935
# 4                    8

# %% [markdown]
# ###  4° Exemplo - e**(-x^2) - cos(x)

# %%
def f(x):
    return math.exp(-x**2) - math.cos(x)
exercicio02(f,[1,3],1.4474142713034,True)
# Out:
# #################Análise do sinal da função#################
# #####################Tabela de análise######################
#         x         1         2         3
# 0    f(x) -0.172423  0.434462  0.990116
# 1   sinal         -         +         +
# #####################Tabela do desafio######################
#         x         1         2
# 0    f(x) -0.172423  0.434462
# 1   sinal         -         +
# ########Tabela de análise dos métodos de refinamento########
#           x = Raíz              Bissecção            Posição Falsa  \
# 0   Dados Iniciais                 [1, 3]                   [1, 3]
# 1                x      1.447414271296237       1.4474142712962368
# 2             f(x)  8.326672684688674e-17  -1.3877787807814457e-17
# 3        Erro em x  7.162936910276585e-12     7.16315895488151e-12
# 4  N° de Iterações                     53                        8
#
#                    Secante
# 0                   [1, 3]
# 1       1.4474142712962368
# 2  -1.3877787807814457e-17
# 3     7.16315895488151e-12
# 4                        6

# %% [markdown]
# ### 5° Exemplo - f(x)= x^6 + sen(2x) - 1, x pertence ao intervalo de  [-1,1]

# %%
def f(x):
    return x**6 + math.sin(x) - 1
exercicio02(f,[-1,1],0.6178439404585,True)
# Out:
# #################Análise do sinal da função#################
# #####################Tabela de análise######################
#         x        -1    0         1
# 0    f(x) -0.841471 -1.0  0.841471
# 1   sinal         -    -         +
# #####################Tabela do desafio######################
#         x        -1         1
# 0    f(x) -0.841471  0.841471
# 1   sinal         -         +
# ########Tabela de análise dos métodos de refinamento########
#           x = Raíz              Bissecção           Posição Falsa  \
# 0   Dados Iniciais                [-1, 1]                 [-1, 1]
# 1                x     0.8075724210000217      0.8075724210000216
# 2             f(x)  2.220446049250313e-16  -2.220446049250313e-16
# 3        Erro em x     0.1897284805415217     0.18972848054152158
# 4  N° de Iterações                     53                      39
#
#                  Secante
# 0                [-1, 1]
# 1     0.8075724210000217
# 2  2.220446049250313e-16
# 3     0.1897284805415217
# 4                     10

# %% [markdown]
# #### Exemplo apocalíptico do ivan

# %%
posicaoFalsa(lambda x: x**2 - 4*x + 4,[0,3])
# Out:
# (2.000010000049882, 1.000008964524568e-10, 100000)

# %%
print(metodoSecante(lambda x: x**2 - 4*x + 4, -1,4,0.0000001,0.0000001))
# Out:
# (2.0003107520199794, 9.656681765335406e-08, 19)
